# %%
#import dependences and modules
import random
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import csv
from citipy import citipy
from config import weather_api_key
from config import g_key

# %% [markdown]
# # Retrieve Weather Data

# %% [markdown]
# ## Generate List of Cities

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the lat_lngs to a list
coordinates = list(lat_lngs)

# %%
#Create a list for holding the names of cities.
cities = []
# Identify the nearest city for each coordinate
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # Append unique cities only
    if city not in cities:
        cities.append(city)
        
# Print length of unique cities
print(len(cities))
# Out:
# 762

# %% [markdown]
# ## Perform API Call
# Get
# - Latitude and longitude
# - Maximum temperature
# - Percent humidity
# - Percent cloudiness
# - Wind speed
# - Weather description (for example, clouds, fog, light rain, clear sky)

# %%
# Starting URL for weather map API call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Initialize list
city_data = []

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i>=50):
        set_count += 1
        record_count = 1
        
    #Create endpoint url for each city.
    city_url = url + "&q=" + city
        
    #log the url,record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        
    #Add 1 to the record count.
    record_count += 1
        
   # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# udenni
# Processing Record 8 of Set 7 | tlaltizapan
# Processing Record 9 of Set 7 | touho
# Processing Record 10 of Set 7 | berbera
# Processing Record 11 of Set 7 | sabha
# Processing Record 12 of Set 7 | erenhot
# Processing Record 13 of Set 7 | marawi
# Processing Record 14 of Set 7 | kollam
# Processing Record 15 of Set 7 | bolshaya murta
# City not found. Skipping...
# Processing Record 16 of Set 7 | karratha
# Processing Record 17 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 7 | brigantine
# Processing Record 19 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 7 | gadwal
# Processing Record 21 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 22 of Set 7 | campbellton
# Processing Record 23 of Set 7 | berlevag
# Processing Record 24 of Set 7 | celestun
# Processing Record 25 of Set 7 | balabac
# Processing Record 26 of Set 7 | yurgamysh
# Processing Record 27 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 7 | ancud
# Processing Record 29 of Set 7 | nantucket
# Processing Record 30 of Set 7 | talaya
# Processing Record 31 of Set 7 | svetlogorsk
# Processing Record 32 of Set 7 | alofi
# Processing Record 33 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 34 of Set 7 | avera
# Processing Record 35 of Set 7 | manzanillo
# Processing Record 36 of Set 7 | cherskiy
# Processing Record 37 of Set 7 | vao
# Processing Record 38 of Set 7 | tatawin
# Processing Record 39 of Set 7 | tahta
# Processing Record 40 of Set 7 | balykshi
# Processing Record 41 of Set 7 | tuatapere
# Processing Record 42 of Set 7 | vanimo
# Processing Record 43 of Set 7 | jiwani
# Processing Record 44 of Set 7 | acarau
# Processing Record 45 of Set 7 | alyangula
# Processing Record 46 of Set 7 | camapua
# Processing Record 47 of Set 7 | mildura
# Processing Record 48 of Set 7 | mangla
# Processing Record 49 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 50 of Set 7 | gorom-gorom
# Processing Record 1 of Set 8 | yar-sale
# Processing Record 2 of Set 8 | kasama
# Processing Record 3 of Set 8 | bontang
# Processing Record 4 of Set 8 | huarmey
# Processing Record 5 of Set 8 | itamarandiba
# Processing Record 6 of Set 8 | quelimane
# Processing Record 7 of Set 8 | king city
# Processing Record 8 of Set 8 | kishi
# Processing Record 9 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record 10 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 11 of Set 8 | baherden
# Processing Record 12 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 8 | bodden town
# Processing Record 14 of Set 8 | maghama
# City not found. Skipping...
# Processing Record 15 of Set 8 | ketchikan
# Processing Record 16 of Set 8 | syava
# Processing Record 17 of Set 8 | salalah
# Processing Record 18 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 19 of Set 8 | coahuayana
# Processing Record 20 of Set 8 | vila do maio
# Processing Record 21 of Set 8 | san ramon
# Processing Record 22 of Set 8 | port hedland
# Processing Record 23 of Set 8 | salinopolis
# Processing Record 24 of Set 8 | harper
# Processing Record 25 of Set 8 | maragogi
# Processing Record 26 of Set 8 | chipinge
# Processing Record 27 of Set 8 | palmer
# Processing Record 28 of Set 8 | carutapera
# Processing Record 29 of Set 8 | cockburn town
# Processing Record 30 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 32 of Set 8 | labuan
# Processing Record 33 of Set 8 | bilma
# Processing Record 34 of Set 8 | murmashi
# Processing Record 35 of Set 8 | santa maria
# Processing Record 36 of Set 8 | jiayuguan
# Processing Record 37 of Set 8 | muzhi
# Processing Record 38 of Set 8 | belchatow
# Processing Record 39 of Set 8 | masaurhi
# Processing Record 40 of Set 8 | urucara
# Processing Record 41 of Set 8 | thinadhoo
# Processing Record 42 of Set 8 | ozgon
# City not found. Skipping...
# Processing Record 43 of Set 8 | carhuamayo
# Processing Record 44 of Set 8 | svetlaya
# Processing Record 45 of Set 8 | rajur
# Processing Record 46 of Set 8 | mae ramat
# Processing Record 47 of Set 8 | general roca
# Processing Record 48 of Set 8 | bathsheba
# Processing Record 49 of Set 8 | nikolskoye
# Processing Record 50 of Set 8 | prabumulih
# Processing Record 1 of Set 9 | yeppoon
# Processing Record 2 of Set 9 | tabou
# Processing Record 3 of Set 9 | ponta delgada
# Processing Record 4 of Set 9 | anapskaya
# Processing Record 5 of Set 9 | krutinka
# Processing Record 6 of Set 9 | trairi
# Processing Record 7 of Set 9 | marfino
# Processing Record 8 of Set 9 | vostok
# Processing Record 9 of Set 9 | saldanha
# Processing Record 10 of Set 9 | thaba-tseka
# Processing Record 11 of Set 9 | samarai
# Processing Record 12 of Set 9 | inhambane
# Processing Record 13 of Set 9 | tupanatinga
# Processing Record 14 of Set 9 | boguchany
# Processing Record 15 of Set 9 | provost
# Processing Record 16 of Set 9 | albesti
# Processing Record 17 of Set 9 | uturoa
# Processing Record 18 of Set 9 | tiarei
# Processing Record 19 of Set 9 | cayenne
# Processing Record 20 of Set 9 | shirgaon
# Processing Record 21 of Set 9 | semporna
# Processing Record 22 of Set 9 | kande
# Processing Record 23 of Set 9 | baghdad
# Processing Record 24 of Set 9 | manta
# Processing Record 25 of Set 9 | nuevo progreso
# Processing Record 26 of Set 9 | klaksvik
# Processing Record 27 of Set 9 | selma
# Processing Record 28 of Set 9 | russell
# Processing Record 29 of Set 9 | wanxian
# Processing Record 30 of Set 9 | andenes
# Processing Record 31 of Set 9 | chapleau
# Processing Record 32 of Set 9 | san vicente
# Processing Record 33 of Set 9 | grand falls
# Processing Record 34 of Set 9 | ucluelet
# Processing Record 35 of Set 9 | togur
# Processing Record 36 of Set 9 | corrales
# Processing Record 37 of Set 9 | dayong
# Processing Record 38 of Set 9 | krasnoturinsk
# Processing Record 39 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 9 | mayya
# Processing Record 41 of Set 9 | juifang
# City not found. Skipping...
# Processing Record 42 of Set 9 | kathu
# Processing Record 43 of Set 9 | krasne
# Processing Record 44 of Set 9 | acambay
# Processing Record 45 of Set 9 | eatonton
# Processing Record 46 of Set 9 | grand gaube
# Processing Record 47 of Set 9 | kantunilkin
# Processing Record 48 of Set 9 | isiro
# Processing Record 49 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 50 of Set 9 | ossora
# Processing Record 1 of Set 10 | moron
# Processing Record 2 of Set 10 | pueblo nuevo
# Processing Record 3 of Set 10 | bam
# Processing Record 4 of Set 10 | reforma
# Processing Record 5 of Set 10 | kruisfontein
# Processing Record 6 of Set 10 | batemans bay
# Processing Record 7 of Set 10 | caetite
# Processing Record 8 of Set 10 | maniitsoq
# Processing Record 9 of Set 10 | camacha
# Processing Record 10 of Set 10 | joshimath
# Processing Record 11 of Set 10 | sisimiut
# Processing Record 12 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 13 of Set 10 | the valley
# Processing Record 14 of Set 10 | garissa
# Processing Record 15 of Set 10 | danilov
# Processing Record 16 of Set 10 | kapit
# Processing Record 17 of Set 10 | tahara
# Processing Record 18 of Set 10 | avrille
# Processing Record 19 of Set 10 | yomitan
# City not found. Skipping...
# Processing Record 20 of Set 10 | sao tome
# Processing Record 21 of Set 10 | opuwo
# Processing Record 22 of Set 10 | ubala
# Processing Record 23 of Set 10 | usinsk
# Processing Record 24 of Set 10 | mehriz
# Processing Record 25 of Set 10 | ziro
# Processing Record 26 of Set 10 | port-gentil
# Processing Record 27 of Set 10 | easton
# Processing Record 28 of Set 10 | tahe
# Processing Record 29 of Set 10 | asosa
# Processing Record 30 of Set 10 | ulladulla
# Processing Record 31 of Set 10 | faanui
# Processing Record 32 of Set 10 | atlantic city
# Processing Record 33 of Set 10 | sokolo
# Processing Record 34 of Set 10 | evensk
# Processing Record 35 of Set 10 | concepcion
# Processing Record 36 of Set 10 | sitka
# Processing Record 37 of Set 10 | bonfim
# Processing Record 38 of Set 10 | wasilla
# Processing Record 39 of Set 10 | zhezkazgan
# Processing Record 40 of Set 10 | nouadhibou
# Processing Record 41 of Set 10 | xai-xai
# Processing Record 42 of Set 10 | vesyegonsk
# Processing Record 43 of Set 10 | selje
# Processing Record 44 of Set 10 | surt
# Processing Record 45 of Set 10 | padang
# Processing Record 46 of Set 10 | port pirie
# Processing Record 47 of Set 10 | vilyuysk
# Processing Record 48 of Set 10 | hecun
# Processing Record 49 of Set 10 | carpinteria
# Processing Record 50 of Set 10 | daru
# Processing Record 1 of Set 11 | bystryy istok
# Processing Record 2 of Set 11 | honiara
# Processing Record 3 of Set 11 | najran
# Processing Record 4 of Set 11 | pasni
# Processing Record 5 of Set 11 | odweyne
# Processing Record 6 of Set 11 | iberia
# Processing Record 7 of Set 11 | lewiston
# Processing Record 8 of Set 11 | greenville
# Processing Record 9 of Set 11 | eirunepe
# Processing Record 10 of Set 11 | sorland
# Processing Record 11 of Set 11 | merauke
# Processing Record 12 of Set 11 | baiao
# Processing Record 13 of Set 11 | tokur
# Processing Record 14 of Set 11 | maun
# Processing Record 15 of Set 11 | magdagachi
# Processing Record 16 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 17 of Set 11 | dzhebariki-khaya
# Processing Record 18 of Set 11 | krasnoselkup
# Processing Record 19 of Set 11 | iwaki
# Processing Record 20 of Set 11 | arbazh
# Processing Record 21 of Set 11 | buraydah
# Processing Record 22 of Set 11 | paamiut
# Processing Record 23 of Set 11 | tura
# Processing Record 24 of Set 11 | rio grande
# Processing Record 25 of Set 11 | serenje
# Processing Record 26 of Set 11 | moree
# Processing Record 27 of Set 11 | lorengau
# Processing Record 28 of Set 11 | kilindoni
# Processing Record 29 of Set 11 | lasa
# Processing Record 30 of Set 11 | okhotsk
# Processing Record 31 of Set 11 | qui nhon
# Processing Record 32 of Set 11 | fort nelson
# Processing Record 33 of Set 11 | rusape
# Processing Record 34 of Set 11 | inta
# Processing Record 35 of Set 11 | kawalu
# Processing Record 36 of Set 11 | srikakulam
# Processing Record 37 of Set 11 | eidfjord
# Processing Record 38 of Set 11 | tiznit
# Processing Record 39 of Set 11 | astana
# Processing Record 40 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 11 | talnakh
# Processing Record 42 of Set 11 | tosya
# Processing Record 43 of Set 11 | half moon bay
# Processing Record 44 of Set 11 | ostersund
# Processing Record 45 of Set 11 | havelock
# Processing Record 46 of Set 11 | kamenka
# Processing Record 47 of Set 11 | nileshwar
# Processing Record 48 of Set 11 | muros
# Processing Record 49 of Set 11 | okakarara
# Processing Record 50 of Set 11 | oranjemund
# Processing Record 1 of Set 12 | mundo nuevo
# Processing Record 2 of Set 12 | koumac
# Processing Record 3 of Set 12 | turukhansk
# Processing Record 4 of Set 12 | siderno
# Processing Record 5 of Set 12 | asau
# Processing Record 6 of Set 12 | rio gallegos
# Processing Record 7 of Set 12 | anadyr
# Processing Record 8 of Set 12 | khandyga
# Processing Record 9 of Set 12 | yerbogachen
# Processing Record 10 of Set 12 | batesville
# Processing Record 11 of Set 12 | los llanos de aridane
# Processing Record 12 of Set 12 | sioux lookout
# Processing Record 13 of Set 12 | neiafu
# Processing Record 14 of Set 12 | mokhsogollokh
# Processing Record 15 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 16 of Set 12 | khash
# Processing Record 17 of Set 12 | benghazi
# Processing Record 18 of Set 12 | ilheus
# Processing Record 19 of Set 12 | kommunar
# Processing Record 20 of Set 12 | villa vazquez
# City not found. Skipping...
# Processing Record 21 of Set 12 | cap malheureux
# Processing Record 22 of Set 12 | iranshahr
# Processing Record 23 of Set 12 | mujiayingzi
# Processing Record 24 of Set 12 | saint-joseph
# Processing Record 25 of Set 12 | aktas
# Processing Record 26 of Set 12 | nhulunbuy
# Processing Record 27 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 28 of Set 12 | kharovsk
# Processing Record 29 of Set 12 | hambantota
# Processing Record 30 of Set 12 | kitimat
# Processing Record 31 of Set 12 | moose factory
# Processing Record 32 of Set 12 | ilinskiy
# Processing Record 33 of Set 12 | perbaungan
# Processing Record 34 of Set 12 | pyay
# Processing Record 35 of Set 12 | bogatyye saby
# Processing Record 36 of Set 12 | labuhan
# Processing Record 37 of Set 12 | chumikan
# Processing Record 38 of Set 12 | shimoda
# Processing Record 39 of Set 12 | umm lajj
# Processing Record 40 of Set 12 | hay river
# Processing Record 41 of Set 12 | ifanadiana
# Processing Record 42 of Set 12 | vicosa do ceara
# Processing Record 43 of Set 12 | tuy hoa
# Processing Record 44 of Set 12 | kayerkan
# Processing Record 45 of Set 12 | malia
# Processing Record 46 of Set 12 | pervoye maya
# Processing Record 47 of Set 12 | kahului
# Processing Record 48 of Set 12 | harindanga
# Processing Record 49 of Set 12 | fairfield
# Processing Record 50 of Set 12 | ambulu
# Processing Record 1 of Set 13 | matara
# Processing Record 2 of Set 13 | constitucion
# Processing Record 3 of Set 13 | lar
# Processing Record 4 of Set 13 | qaqortoq
# Processing Record 5 of Set 13 | ascension
# Processing Record 6 of Set 13 | hibbing
# Processing Record 7 of Set 13 | san ignacio
# Processing Record 8 of Set 13 | tobolsk
# Processing Record 9 of Set 13 | wodonga
# Processing Record 10 of Set 13 | neftcala
# Processing Record 11 of Set 13 | anopino
# Processing Record 12 of Set 13 | choszczno
# Processing Record 13 of Set 13 | bundaberg
# Processing Record 14 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 15 of Set 13 | methven
# Processing Record 16 of Set 13 | ryotsu
# Processing Record 17 of Set 13 | bongandanga
# Processing Record 18 of Set 13 | mecca
# Processing Record 19 of Set 13 | suntar
# Processing Record 20 of Set 13 | srivardhan
# Processing Record 21 of Set 13 | matagami
# Processing Record 22 of Set 13 | jizan
# Processing Record 23 of Set 13 | sivas
# Processing Record 24 of Set 13 | ternate
# Processing Record 25 of Set 13 | abonnema
# Processing Record 26 of Set 13 | moshkovo
# Processing Record 27 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 13 | bac lieu
# Processing Record 29 of Set 13 | bilibino
# Processing Record 30 of Set 13 | gasa
# Processing Record 31 of Set 13 | clyde river
# Processing Record 32 of Set 13 | kangaatsiaq
# Processing Record 33 of Set 13 | lubango
# Processing Record 34 of Set 13 | kourou
# Processing Record 35 of Set 13 | mayor pablo lagerenza
# Processing Record 36 of Set 13 | olafsvik
# Processing Record 37 of Set 13 | stromness
# Processing Record 38 of Set 13 | kieta
# Processing Record 39 of Set 13 | khakhea
# Processing Record 40 of Set 13 | shagamu
# Processing Record 41 of Set 13 | charleville-mezieres
# Processing Record 42 of Set 13 | parabel
# Processing Record 43 of Set 13 | mao
# Processing Record 44 of Set 13 | simbahan
# Processing Record 45 of Set 13 | mercedes
# Processing Record 46 of Set 13 | navabad
# City not found. Skipping...
# Processing Record 47 of Set 13 | gouyave
# Processing Record 48 of Set 13 | shingu
# Processing Record 49 of Set 13 | maiduguri
# Processing Record 50 of Set 13 | tucurui
# Processing Record 1 of Set 14 | ciudad bolivar
# Processing Record 2 of Set 14 | newport
# Processing Record 3 of Set 14 | kati
# Processing Record 4 of Set 14 | mwinilunga
# Processing Record 5 of Set 14 | dedza
# Processing Record 6 of Set 14 | kapasan
# Processing Record 7 of Set 14 | birao
# Processing Record 8 of Set 14 | broome
# Processing Record 9 of Set 14 | brekstad
# Processing Record 10 of Set 14 | vila velha
# Processing Record 11 of Set 14 | izhma
# Processing Record 12 of Set 14 | roebourne
# Processing Record 13 of Set 14 | mackay
# Processing Record 14 of Set 14 | atar
# Processing Record 15 of Set 14 | gilgil
# City not found. Skipping...
# Processing Record 16 of Set 14 | batagay
# Processing Record 17 of Set 14 | trincomalee
# Processing Record 18 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 19 of Set 14 | urumqi
# Processing Record 20 of Set 14 | vanavara
# Processing Record 21 of Set 14 | huadian
# Processing Record 22 of Set 14 | coquimbo
# Processing Record 23 of Set 14 | villazon
# Processing Record 24 of Set 14 | lagoa
# Processing Record 25 of Set 14 | selenduma
# Processing Record 26 of Set 14 | ochamchira
# Processing Record 27 of Set 14 | matamoros
# Processing Record 28 of Set 14 | zaozerne
# Processing Record 29 of Set 14 | aybak
# City not found. Skipping...
# Processing Record 30 of Set 14 | awjilah
# Processing Record 31 of Set 14 | rabat
# Processing Record 32 of Set 14 | san patricio
# Processing Record 33 of Set 14 | soloneshnoye
# Processing Record 34 of Set 14 | gorontalo
# Processing Record 35 of Set 14 | huanren
# Processing Record 36 of Set 14 | amalapuram
# Processing Record 37 of Set 14 | moindou
# Processing Record 38 of Set 14 | kununurra
# Processing Record 39 of Set 14 | volovo
# Processing Record 40 of Set 14 | mandalgovi
# Processing Record 41 of Set 14 | sao geraldo do araguaia
# Processing Record 42 of Set 14 | camopi
# Processing Record 43 of Set 14 | howard springs
# Processing Record 44 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 45 of Set 14 | tungor
# Processing Record 46 of Set 14 | de-kastri
# Processing Record 47 of Set 14 | saint-pierre
# Processing Record 48 of Set 14 | diamantino
# Processing Record 49 of Set 14 | ballina
# Processing Record 50 of Set 14 | wucheng
# Processing Record 1 of Set 15 | cantagallo
# Processing Record 2 of Set 15 | baripada
# Processing Record 3 of Set 15 | tomatlan
# Processing Record 4 of Set 15 | nacala
# Processing Record 5 of Set 15 | jishou
# Processing Record 6 of Set 15 | pacifica
# Processing Record 7 of Set 15 | tanete
# Processing Record 8 of Set 15 | dukat
# Processing Record 9 of Set 15 | sault sainte marie
# Processing Record 10 of Set 15 | tarko-sale
# Processing Record 11 of Set 15 | barentu
# Processing Record 12 of Set 15 | kaeo
# Processing Record 13 of Set 15 | shelburne
# Processing Record 14 of Set 15 | zambezi
# Processing Record 15 of Set 15 | whitehorse
# Processing Record 16 of Set 15 | ampanihy
# Processing Record 17 of Set 15 | axim
# Processing Record 18 of Set 15 | jacmel
# Processing Record 19 of Set 15 | guatire
# Processing Record 20 of Set 15 | praia
# Processing Record 21 of Set 15 | chapadinha
# Processing Record 22 of Set 15 | nabire
# Processing Record 23 of Set 15 | husavik
# Processing Record 24 of Set 15 | antalaha
# Processing Record 25 of Set 15 | praia da vitoria
# Processing Record 26 of Set 15 | nueva concepcion
# Processing Record 27 of Set 15 | ulaangom
# Processing Record 28 of Set 15 | ostrovnoy
# Processing Record 29 of Set 15 | jabinyanah
# Processing Record 30 of Set 15 | sterling
# Processing Record 31 of Set 15 | pontes e lacerda
# Processing Record 32 of Set 15 | sistranda
# Processing Record 33 of Set 15 | salamanca
# Processing Record 34 of Set 15 | providencia
# Processing Record 35 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 36 of Set 15 | sasykoli
# Processing Record 37 of Set 15 | iturama
# Processing Record 38 of Set 15 | bonthe
# Processing Record 39 of Set 15 | luganville
# Processing Record 40 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 15 | aki
# Processing Record 42 of Set 15 | san jose pinula
# Processing Record 43 of Set 15 | bethanien
# Processing Record 44 of Set 15 | holme
# Processing Record 45 of Set 15 | hato mayor
# Processing Record 46 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 15 | beloha
# Processing Record 48 of Set 15 | manjacaze
# Processing Record 49 of Set 15 | pimentel
# Processing Record 50 of Set 15 | boulder
# Processing Record 1 of Set 16 | julio de castilhos
# Processing Record 2 of Set 16 | huainan
# Processing Record 3 of Set 16 | kaniama
# Processing Record 4 of Set 16 | bonoua
# Processing Record 5 of Set 16 | halifax
# Processing Record 6 of Set 16 | zeya
# Processing Record 7 of Set 16 | xining
# Processing Record 8 of Set 16 | santa lucia
# Processing Record 9 of Set 16 | sao filipe
# Processing Record 10 of Set 16 | morondava
# Processing Record 11 of Set 16 | omboue
# Processing Record 12 of Set 16 | codrington
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create dataframe to hold the data
city_data_df=pd.DataFrame(city_data)
city_data_df
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Contamana  -7.3333  -75.0167     80.91        79         100
# 1         Pitimbu  -7.4706  -34.8086     77.59        83          39
# 2          Hobart -42.8794  147.3294     52.11        82          75
# 3       Cape Town -33.9258   18.4232     68.41        32           0
# 4    Punta Arenas -53.1500  -70.9167     41.11        75           0
# ..            ...      ...       ...       ...       ...         ...
# 694   Santa Lucia  27.9117  -15.5407     60.76        73          40
# 695    Sao Filipe  14.8961  -24.4956     75.36        70          22
# 696     Morondava -20.2833   44.2833     73.53        56          36
# 697        Omboue  -1.5746    9.2618     76.17        94          84
# 698    Codrington -38.2667  141.9667     56.16        63         100
#
#      Wind Speed Country                 Date
# 0          2.73      PE  2021-06-06 21:39:19
# 1         11.90      BR  2021-06-06 21:39:19
# 2          7.27      AU  2021-06-06 21:30:17
# 3         10.80      ZA  2021-06-06 21:29:17
# 4         11.83      CL  2021-06-06 21:31:10
# ..          ...     ...                  ...
# 694       12.41      ES  2021-06-06 21:44:00
# 695       10.29      CV  2021-06-06 21:44:00
# 696       14.36      MG  2021-06-06 21:44:00
# 697        4.83      GA  2021-06-06 21:44:01
# 698       21.32      AU  2021-06-06 21:44:01
#
# [699 rows x 9 columns]

# %%
# Export the dataframe to csv file.
city_data_df.to_csv("WeatherPy_Database.csv", index_label="City ID")
