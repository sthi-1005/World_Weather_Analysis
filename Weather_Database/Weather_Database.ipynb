# %%
#import dependences and modules
import random
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import csv
from citipy import citipy
from config import weather_api_key
from config import g_key

# %% [markdown]
# # Retrieve Weather Data

# %% [markdown]
# ## Generate List of Cities

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the lat_lngs to a list
coordinates = list(lat_lngs)

# %%
#Create a list for holding the names of cities.
cities = []
# Identify the nearest city for each coordinate
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # Append unique cities only
    if city not in cities:
        cities.append(city)
        
# Print length of unique cities
print(len(cities))
# Out:
# 789

# %% [markdown]
# ## Perform API Call
# Get
# - Latitude and longitude
# - Maximum temperature
# - Percent humidity
# - Percent cloudiness
# - Wind speed
# - Weather description (for example, clouds, fog, light rain, clear sky)

# %%
# Starting URL for weather map API call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Initialize list
city_data = []

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i>=50):
        set_count += 1
        record_count = 1
        
    #Create endpoint url for each city.
    city_url = url + "&q=" + city
        
    #log the url,record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        
    #Add 1 to the record count.
    record_count += 1
        
   # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descrip = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_descrip,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# of Set 7 | fortuna
# Processing Record 37 of Set 7 | miri
# Processing Record 38 of Set 7 | lubango
# Processing Record 39 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 40 of Set 7 | mindelo
# Processing Record 41 of Set 7 | ozernovskiy
# Processing Record 42 of Set 7 | asau
# Processing Record 43 of Set 7 | mukhanovo
# City not found. Skipping...
# Processing Record 44 of Set 7 | klaksvik
# Processing Record 45 of Set 7 | praia da vitoria
# Processing Record 46 of Set 7 | rongcheng
# Processing Record 47 of Set 7 | dzhebariki-khaya
# Processing Record 48 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 7 | marsh harbour
# Processing Record 50 of Set 7 | portland
# Processing Record 1 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 2 of Set 8 | sumbawanga
# Processing Record 3 of Set 8 | oyama
# Processing Record 4 of Set 8 | damietta
# Processing Record 5 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 8 | serta
# Processing Record 7 of Set 8 | ribeira grande
# Processing Record 8 of Set 8 | erenhot
# Processing Record 9 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 8 | culaman
# Processing Record 12 of Set 8 | dikson
# Processing Record 13 of Set 8 | christchurch
# Processing Record 14 of Set 8 | ponta delgada
# Processing Record 15 of Set 8 | kinshasa
# Processing Record 16 of Set 8 | vilcun
# Processing Record 17 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 8 | mount isa
# Processing Record 19 of Set 8 | freeport
# Processing Record 20 of Set 8 | hawera
# Processing Record 21 of Set 8 | leningradskiy
# Processing Record 22 of Set 8 | husavik
# Processing Record 23 of Set 8 | san carlos del zulia
# Processing Record 24 of Set 8 | gat
# Processing Record 25 of Set 8 | okha
# Processing Record 26 of Set 8 | nishihara
# Processing Record 27 of Set 8 | pisco
# Processing Record 28 of Set 8 | necochea
# Processing Record 29 of Set 8 | aksarka
# Processing Record 30 of Set 8 | norden
# Processing Record 31 of Set 8 | baoro
# Processing Record 32 of Set 8 | tura
# Processing Record 33 of Set 8 | gerash
# Processing Record 34 of Set 8 | sabang
# Processing Record 35 of Set 8 | havelock
# Processing Record 36 of Set 8 | zaraza
# Processing Record 37 of Set 8 | pundaguitan
# Processing Record 38 of Set 8 | airai
# Processing Record 39 of Set 8 | petatlan
# Processing Record 40 of Set 8 | urubamba
# Processing Record 41 of Set 8 | padang
# Processing Record 42 of Set 8 | broken hill
# Processing Record 43 of Set 8 | dhidhdhoo
# Processing Record 44 of Set 8 | pringsewu
# Processing Record 45 of Set 8 | hurghada
# Processing Record 46 of Set 8 | dakar
# Processing Record 47 of Set 8 | doha
# Processing Record 48 of Set 8 | tabou
# Processing Record 49 of Set 8 | sokolo
# Processing Record 50 of Set 8 | belmonte
# Processing Record 1 of Set 9 | ipora
# Processing Record 2 of Set 9 | la ronge
# Processing Record 3 of Set 9 | katangli
# Processing Record 4 of Set 9 | malakal
# Processing Record 5 of Set 9 | havre-saint-pierre
# Processing Record 6 of Set 9 | susangerd
# Processing Record 7 of Set 9 | kirkuk
# Processing Record 8 of Set 9 | crawfordsville
# Processing Record 9 of Set 9 | nuuk
# Processing Record 10 of Set 9 | cleveland
# Processing Record 11 of Set 9 | port lincoln
# Processing Record 12 of Set 9 | clarence town
# Processing Record 13 of Set 9 | henties bay
# Processing Record 14 of Set 9 | kalmunai
# Processing Record 15 of Set 9 | kahului
# Processing Record 16 of Set 9 | severomuysk
# Processing Record 17 of Set 9 | tamandare
# Processing Record 18 of Set 9 | guerrero negro
# Processing Record 19 of Set 9 | teya
# Processing Record 20 of Set 9 | kieta
# Processing Record 21 of Set 9 | qom
# Processing Record 22 of Set 9 | buchanan
# Processing Record 23 of Set 9 | vanavara
# Processing Record 24 of Set 9 | kozhva
# Processing Record 25 of Set 9 | cobija
# Processing Record 26 of Set 9 | hamilton
# Processing Record 27 of Set 9 | ixtapa
# Processing Record 28 of Set 9 | heze
# Processing Record 29 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 9 | sovetskaya
# Processing Record 31 of Set 9 | aklavik
# Processing Record 32 of Set 9 | sovetskiy
# Processing Record 33 of Set 9 | san bartolome de tirajana
# Processing Record 34 of Set 9 | surt
# Processing Record 35 of Set 9 | uglezavodsk
# Processing Record 36 of Set 9 | deputatskiy
# Processing Record 37 of Set 9 | rio verde de mato grosso
# Processing Record 38 of Set 9 | saldanha
# Processing Record 39 of Set 9 | ternate
# Processing Record 40 of Set 9 | khorixas
# Processing Record 41 of Set 9 | tashtyp
# Processing Record 42 of Set 9 | ambositra
# Processing Record 43 of Set 9 | wufeng
# Processing Record 44 of Set 9 | abu samrah
# Processing Record 45 of Set 9 | piney green
# Processing Record 46 of Set 9 | saint-leu
# Processing Record 47 of Set 9 | ati
# Processing Record 48 of Set 9 | faya
# Processing Record 49 of Set 9 | gazanjyk
# Processing Record 50 of Set 9 | mogocha
# Processing Record 1 of Set 10 | nyrob
# Processing Record 2 of Set 10 | pilar
# Processing Record 3 of Set 10 | russell
# Processing Record 4 of Set 10 | petrolina
# Processing Record 5 of Set 10 | ulladulla
# Processing Record 6 of Set 10 | yellandu
# Processing Record 7 of Set 10 | antofagasta
# Processing Record 8 of Set 10 | uyuni
# Processing Record 9 of Set 10 | hofn
# Processing Record 10 of Set 10 | yazman
# Processing Record 11 of Set 10 | ahipara
# Processing Record 12 of Set 10 | riyadh
# Processing Record 13 of Set 10 | santa elena
# Processing Record 14 of Set 10 | verkhovazhye
# Processing Record 15 of Set 10 | yulara
# Processing Record 16 of Set 10 | dedovichi
# Processing Record 17 of Set 10 | augusto correa
# Processing Record 18 of Set 10 | sabzevar
# Processing Record 19 of Set 10 | sao filipe
# Processing Record 20 of Set 10 | seoul
# Processing Record 21 of Set 10 | bykovo
# Processing Record 22 of Set 10 | kijang
# Processing Record 23 of Set 10 | neuquen
# Processing Record 24 of Set 10 | vaitape
# Processing Record 25 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 26 of Set 10 | strelka
# Processing Record 27 of Set 10 | guiglo
# Processing Record 28 of Set 10 | marsa matruh
# Processing Record 29 of Set 10 | tessalit
# Processing Record 30 of Set 10 | paita
# Processing Record 31 of Set 10 | lahaina
# Processing Record 32 of Set 10 | olinda
# Processing Record 33 of Set 10 | ucluelet
# Processing Record 34 of Set 10 | omboue
# Processing Record 35 of Set 10 | enshi
# Processing Record 36 of Set 10 | reconquista
# Processing Record 37 of Set 10 | tunduru
# City not found. Skipping...
# Processing Record 38 of Set 10 | blagoyevo
# Processing Record 39 of Set 10 | monrovia
# Processing Record 40 of Set 10 | wenling
# Processing Record 41 of Set 10 | pitimbu
# Processing Record 42 of Set 10 | annau
# Processing Record 43 of Set 10 | weinan
# Processing Record 44 of Set 10 | puerto madryn
# Processing Record 45 of Set 10 | bengkulu
# Processing Record 46 of Set 10 | salalah
# Processing Record 47 of Set 10 | demba
# Processing Record 48 of Set 10 | santa gertrudis
# Processing Record 49 of Set 10 | houma
# Processing Record 50 of Set 10 | buraydah
# Processing Record 1 of Set 11 | pareora
# Processing Record 2 of Set 11 | lavrentiya
# Processing Record 3 of Set 11 | olafsvik
# Processing Record 4 of Set 11 | sinnamary
# Processing Record 5 of Set 11 | poya
# Processing Record 6 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 11 | estelle
# Processing Record 8 of Set 11 | aliaga
# Processing Record 9 of Set 11 | greencastle
# Processing Record 10 of Set 11 | tenenkou
# Processing Record 11 of Set 11 | gravdal
# Processing Record 12 of Set 11 | chiredzi
# Processing Record 13 of Set 11 | igdir
# Processing Record 14 of Set 11 | ancud
# Processing Record 15 of Set 11 | macklin
# Processing Record 16 of Set 11 | chumikan
# Processing Record 17 of Set 11 | rapla
# Processing Record 18 of Set 11 | port keats
# Processing Record 19 of Set 11 | kihei
# Processing Record 20 of Set 11 | valparaiso
# Processing Record 21 of Set 11 | praya
# Processing Record 22 of Set 11 | kang
# Processing Record 23 of Set 11 | pacifica
# Processing Record 24 of Set 11 | orange
# Processing Record 25 of Set 11 | richards bay
# Processing Record 26 of Set 11 | olean
# Processing Record 27 of Set 11 | moose factory
# Processing Record 28 of Set 11 | nome
# Processing Record 29 of Set 11 | ilulissat
# Processing Record 30 of Set 11 | san carlos de bariloche
# Processing Record 31 of Set 11 | khandyga
# Processing Record 32 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 33 of Set 11 | buala
# Processing Record 34 of Set 11 | mirnyy
# Processing Record 35 of Set 11 | teknaf
# Processing Record 36 of Set 11 | los llanos de aridane
# Processing Record 37 of Set 11 | bolobo
# Processing Record 38 of Set 11 | qarqin
# Processing Record 39 of Set 11 | taoudenni
# Processing Record 40 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 11 | ceuta
# Processing Record 42 of Set 11 | bambanglipuro
# Processing Record 43 of Set 11 | oranjestad
# Processing Record 44 of Set 11 | solnechnyy
# Processing Record 45 of Set 11 | marrakesh
# Processing Record 46 of Set 11 | atambua
# Processing Record 47 of Set 11 | ormara
# Processing Record 48 of Set 11 | agvali
# Processing Record 49 of Set 11 | margate
# Processing Record 50 of Set 11 | komsomolskiy
# Processing Record 1 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 2 of Set 12 | north myrtle beach
# Processing Record 3 of Set 12 | rawson
# Processing Record 4 of Set 12 | pangkalanbuun
# Processing Record 5 of Set 12 | bukoba
# Processing Record 6 of Set 12 | izhevskoye
# Processing Record 7 of Set 12 | port-cartier
# Processing Record 8 of Set 12 | alexandria
# Processing Record 9 of Set 12 | plyussa
# Processing Record 10 of Set 12 | biak
# Processing Record 11 of Set 12 | jawhar
# Processing Record 12 of Set 12 | rocha
# Processing Record 13 of Set 12 | iowa city
# Processing Record 14 of Set 12 | sur
# Processing Record 15 of Set 12 | yuxia
# Processing Record 16 of Set 12 | hami
# Processing Record 17 of Set 12 | kenitra
# Processing Record 18 of Set 12 | somerset west
# Processing Record 19 of Set 12 | beloha
# Processing Record 20 of Set 12 | playas
# Processing Record 21 of Set 12 | guadalupe y calvo
# Processing Record 22 of Set 12 | ibanda
# Processing Record 23 of Set 12 | rio brilhante
# Processing Record 24 of Set 12 | mattru
# Processing Record 25 of Set 12 | mae ramat
# Processing Record 26 of Set 12 | araguatins
# City not found. Skipping...
# Processing Record 27 of Set 12 | espanola
# Processing Record 28 of Set 12 | ilave
# Processing Record 29 of Set 12 | lingdong
# Processing Record 30 of Set 12 | shingu
# Processing Record 31 of Set 12 | kandrian
# Processing Record 32 of Set 12 | sirkali
# City not found. Skipping...
# Processing Record 33 of Set 12 | marquard
# Processing Record 34 of Set 12 | boa vista
# Processing Record 35 of Set 12 | baghmara
# Processing Record 36 of Set 12 | bu salim
# City not found. Skipping...
# Processing Record 37 of Set 12 | la celia
# Processing Record 38 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 12 | astana
# Processing Record 40 of Set 12 | quatre cocos
# Processing Record 41 of Set 12 | parksville
# Processing Record 42 of Set 12 | domoni
# Processing Record 43 of Set 12 | gayeri
# Processing Record 44 of Set 12 | vanimo
# Processing Record 45 of Set 12 | nouadhibou
# Processing Record 46 of Set 12 | thibodaux
# Processing Record 47 of Set 12 | bijie
# Processing Record 48 of Set 12 | nelson bay
# Processing Record 49 of Set 12 | jimo
# Processing Record 50 of Set 12 | tromso
# Processing Record 1 of Set 13 | gidam
# Processing Record 2 of Set 13 | noumea
# Processing Record 3 of Set 13 | veraval
# Processing Record 4 of Set 13 | nanning
# Processing Record 5 of Set 13 | mlimba
# Processing Record 6 of Set 13 | barmer
# Processing Record 7 of Set 13 | kortkeros
# Processing Record 8 of Set 13 | safford
# Processing Record 9 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 10 of Set 13 | guozhen
# Processing Record 11 of Set 13 | tuatapere
# Processing Record 12 of Set 13 | nurobod
# Processing Record 13 of Set 13 | lasa
# Processing Record 14 of Set 13 | udachnyy
# Processing Record 15 of Set 13 | shimoda
# Processing Record 16 of Set 13 | vila velha
# Processing Record 17 of Set 13 | chissamba
# Processing Record 18 of Set 13 | qena
# Processing Record 19 of Set 13 | huimanguillo
# Processing Record 20 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 13 | vestmannaeyjar
# Processing Record 22 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 23 of Set 13 | mandan
# Processing Record 24 of Set 13 | malindi
# Processing Record 25 of Set 13 | labuhan
# Processing Record 26 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 27 of Set 13 | shache
# Processing Record 28 of Set 13 | fujin
# Processing Record 29 of Set 13 | nantucket
# Processing Record 30 of Set 13 | ambon
# Processing Record 31 of Set 13 | svetlyy
# Processing Record 32 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 13 | mhango
# Processing Record 34 of Set 13 | cherlak
# Processing Record 35 of Set 13 | tomatlan
# Processing Record 36 of Set 13 | ambilobe
# Processing Record 37 of Set 13 | ekibastuz
# Processing Record 38 of Set 13 | muisne
# Processing Record 39 of Set 13 | suntar
# Processing Record 40 of Set 13 | platanos
# Processing Record 41 of Set 13 | sobolevo
# Processing Record 42 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 13 | ulaanbaatar
# Processing Record 44 of Set 13 | nipawin
# Processing Record 45 of Set 13 | binga
# Processing Record 46 of Set 13 | saratoga springs
# Processing Record 47 of Set 13 | palana
# Processing Record 48 of Set 13 | ardatov
# Processing Record 49 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 1 of Set 14 | mikhaylovka
# Processing Record 2 of Set 14 | cap-aux-meules
# Processing Record 3 of Set 14 | auki
# Processing Record 4 of Set 14 | puerto narino
# Processing Record 5 of Set 14 | cap malheureux
# Processing Record 6 of Set 14 | cuamba
# Processing Record 7 of Set 14 | general pico
# Processing Record 8 of Set 14 | vanderhoof
# Processing Record 9 of Set 14 | terrace bay
# Processing Record 10 of Set 14 | aswan
# Processing Record 11 of Set 14 | paramonga
# Processing Record 12 of Set 14 | dolores
# Processing Record 13 of Set 14 | malinovoye ozero
# Processing Record 14 of Set 14 | basco
# Processing Record 15 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 14 | krasnaya gora
# Processing Record 17 of Set 14 | lillooet
# Processing Record 18 of Set 14 | linxia
# Processing Record 19 of Set 14 | chicama
# Processing Record 20 of Set 14 | sola
# Processing Record 21 of Set 14 | khonsa
# Processing Record 22 of Set 14 | dir
# Processing Record 23 of Set 14 | tyulyachi
# Processing Record 24 of Set 14 | mehamn
# Processing Record 25 of Set 14 | dicabisagan
# Processing Record 26 of Set 14 | taksimo
# Processing Record 27 of Set 14 | matagami
# Processing Record 28 of Set 14 | capim grosso
# Processing Record 29 of Set 14 | pokhara
# Processing Record 30 of Set 14 | neryungri
# Processing Record 31 of Set 14 | itarema
# Processing Record 32 of Set 14 | bhinga
# Processing Record 33 of Set 14 | chernyshevskiy
# Processing Record 34 of Set 14 | zima
# Processing Record 35 of Set 14 | samarai
# Processing Record 36 of Set 14 | beausejour
# Processing Record 37 of Set 14 | tevriz
# Processing Record 38 of Set 14 | iranshahr
# Processing Record 39 of Set 14 | bijar
# Processing Record 40 of Set 14 | noyabrsk
# Processing Record 41 of Set 14 | sorong
# Processing Record 42 of Set 14 | along
# Processing Record 43 of Set 14 | sokoni
# Processing Record 44 of Set 14 | namatanai
# Processing Record 45 of Set 14 | progreso
# Processing Record 46 of Set 14 | calamar
# Processing Record 47 of Set 14 | metro
# Processing Record 48 of Set 14 | abu kamal
# Processing Record 49 of Set 14 | saurimo
# Processing Record 50 of Set 14 | broome
# Processing Record 1 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 2 of Set 15 | kidal
# Processing Record 3 of Set 15 | kawalu
# Processing Record 4 of Set 15 | lakes entrance
# Processing Record 5 of Set 15 | conselheiro pena
# Processing Record 6 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 7 of Set 15 | weiden
# Processing Record 8 of Set 15 | satu mare
# Processing Record 9 of Set 15 | wanning
# Processing Record 10 of Set 15 | chapais
# Processing Record 11 of Set 15 | pailon
# Processing Record 12 of Set 15 | jalalabad
# Processing Record 13 of Set 15 | marabba
# Processing Record 14 of Set 15 | antanifotsy
# Processing Record 15 of Set 15 | garissa
# Processing Record 16 of Set 15 | san policarpo
# Processing Record 17 of Set 15 | fort nelson
# Processing Record 18 of Set 15 | the valley
# Processing Record 19 of Set 15 | launceston
# Processing Record 20 of Set 15 | sasso marconi
# Processing Record 21 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 22 of Set 15 | melfi
# Processing Record 23 of Set 15 | destin
# Processing Record 24 of Set 15 | muros
# Processing Record 25 of Set 15 | muyezerskiy
# Processing Record 26 of Set 15 | martinsville
# Processing Record 27 of Set 15 | hargeysa
# Processing Record 28 of Set 15 | tumaco
# Processing Record 29 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 30 of Set 15 | kurumkan
# Processing Record 31 of Set 15 | linjiang
# Processing Record 32 of Set 15 | juba
# Processing Record 33 of Set 15 | maltahohe
# Processing Record 34 of Set 15 | ivdel
# Processing Record 35 of Set 15 | sitangkai
# Processing Record 36 of Set 15 | erzin
# Processing Record 37 of Set 15 | haines junction
# Processing Record 38 of Set 15 | mujiayingzi
# Processing Record 39 of Set 15 | betki
# City not found. Skipping...
# Processing Record 40 of Set 15 | bela
# Processing Record 41 of Set 15 | dunedin
# Processing Record 42 of Set 15 | valreas
# Processing Record 43 of Set 15 | huangchuan
# Processing Record 44 of Set 15 | mecca
# Processing Record 45 of Set 15 | coahuayana
# Processing Record 46 of Set 15 | ratnagiri
# Processing Record 47 of Set 15 | santa maria
# Processing Record 48 of Set 15 | saint-louis
# Processing Record 49 of Set 15 | port hawkesbury
# Processing Record 50 of Set 15 | lichinga
# Processing Record 1 of Set 16 | rio gallegos
# Processing Record 2 of Set 16 | xining
# Processing Record 3 of Set 16 | humaita
# Processing Record 4 of Set 16 | oksfjord
# Processing Record 5 of Set 16 | whitianga
# Processing Record 6 of Set 16 | sarangani
# Processing Record 7 of Set 16 | ca mau
# Processing Record 8 of Set 16 | mayskiy
# Processing Record 9 of Set 16 | seymchan
# Processing Record 10 of Set 16 | asfi
# Processing Record 11 of Set 16 | banjar
# Processing Record 12 of Set 16 | curuguaty
# Processing Record 13 of Set 16 | changji
# Processing Record 14 of Set 16 | lorengau
# Processing Record 15 of Set 16 | bontang
# Processing Record 16 of Set 16 | skalistyy
# City not found. Skipping...
# Processing Record 17 of Set 16 | mao
# Processing Record 18 of Set 16 | paradwip
# City not found. Skipping...
# Processing Record 19 of Set 16 | paamiut
# Processing Record 20 of Set 16 | horta
# Processing Record 21 of Set 16 | manosque
# Processing Record 22 of Set 16 | sakakah
# Processing Record 23 of Set 16 | zanjan
# Processing Record 24 of Set 16 | yongan
# Processing Record 25 of Set 16 | mahaicony
# City not found. Skipping...
# Processing Record 26 of Set 16 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 16 | michigan city
# Processing Record 28 of Set 16 | camacupa
# Processing Record 29 of Set 16 | garden city
# Processing Record 30 of Set 16 | zdvinsk
# Processing Record 31 of Set 16 | ramasukha
# City not found. Skipping...
# Processing Record 32 of Set 16 | gatton
# Processing Record 33 of Set 16 | raton
# Processing Record 34 of Set 16 | sjovegan
# Processing Record 35 of Set 16 | kapoeta
# Processing Record 36 of Set 16 | korla
# Processing Record 37 of Set 16 | lashio
# Processing Record 38 of Set 16 | mushie
# Processing Record 39 of Set 16 | manaure
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create dataframe to hold the data
city_data_df=pd.DataFrame(city_data)
city_data_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Saskylakh  71.9167  114.0833     39.24        56          77
# 1           Mataura -46.1927  168.8643     49.48        77          59
# 2    Port Macquarie -31.4333  152.9167     50.90        60           5
# 3        Dera Bugti  29.0307   69.1510     87.87        47           0
# 4        Port Hardy  50.6996 -127.4199     55.58        71          75
# ..              ...      ...       ...       ...       ...         ...
# 718         Kapoeta   4.7717   33.5903     82.04        40          52
# 719           Korla  41.7597   86.1469     70.47        39          39
# 720          Lashio  22.9333   97.7500     67.86        98         100
# 721          Mushie  -3.0167   16.9000     72.81        89          76
# 722         Manaure  11.7751  -72.4445     82.65        69         100
#
#      Wind Speed Country Current Description                 Date
# 0          4.59      RU       broken clouds  2021-06-06 22:35:33
# 1          3.38      NZ       broken clouds  2021-06-06 22:34:15
# 2          4.45      AU           clear sky  2021-06-06 22:31:26
# 3          5.08      PK           clear sky  2021-06-06 22:35:34
# 4         14.97      CA       broken clouds  2021-06-06 22:34:21
# ..          ...     ...                 ...                  ...
# 718        5.35      SS       broken clouds  2021-06-06 22:39:43
# 719        9.51      CN    scattered clouds  2021-06-06 22:39:44
# 720        0.69      MM     overcast clouds  2021-06-06 22:39:44
# 721        4.34      CD       broken clouds  2021-06-06 22:39:44
# 722       21.34      CO     overcast clouds  2021-06-06 22:39:45
#
# [723 rows x 10 columns]

# %%
# Export the dataframe to csv file.
city_data_df.to_csv("WeatherPy_Database.csv", index_label="City ID")
